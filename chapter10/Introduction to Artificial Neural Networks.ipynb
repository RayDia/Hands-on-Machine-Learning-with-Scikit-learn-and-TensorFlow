# %% [markdown]
# ## 使用TF的高级API
#
# now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
# root_logdir = "tf_logs"
# logdir = "{}/run-{}/".format(root_logdir, now)

# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("../../tensorflow/MNIST_data")
# Out:
# Extracting ../../tensorflow/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../tensorflow/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../tensorflow/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../tensorflow/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
X_train = mnist.train.images
X_test = mnist.test.images
y_train = mnist.train.labels.astype("int")
y_test = mnist.test.labels.astype("int")

# %%
import tensorflow as tf

config = tf.contrib.learn.RunConfig(tf_random_seed=42)

feature_cols = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10,
                              feature_columns=feature_cols, config=config)
dnn_clf = tf.contrib.learn.SKCompat(dnn_clf)
dnn_clf.fit(X_train, y_train, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpcdilxemo
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3a4d231550>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': 42, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpcdilxemo'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpcdilxemo/model.ckpt.
# INFO:tensorflow:loss = 2.4005778, step = 1
# INFO:tensorflow:global_step/sec: 403.917
# INFO:tensorflow:loss = 0.31267592, step = 101 (0.248 sec)
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred = dnn_clf.predict(X_test)
accuracy_score(y_test, y_pred['classes'])
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tmpcdilxemo/model.ckpt-40000
# 0.984

# %% [markdown]
# ## 不使用API

# %%
import tensorflow as tf

n_inputs = 28 * 28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.Session() as sess:
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons),stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relue(z)
        else:
            return z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1",
                          activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2",
                          activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name="outputs")

# %% [markdown]
# ### 使用 tf.layers.dense 来代替neuron_layer

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                             activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                             activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")

# %% [markdown]
# ### 损失函数

# %%
## sparse_softmax_cross_entropy_with_logits 不会报type错 int64 和 float32
#softmax_cross_entropy_with_logits（）的另一个函数，该函数在标签one-hot载体的形式（而不是整数0至类的数目减1）
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %% [markdown]
# ## 训练模型
# 有了dnn和损失函数，可以开始用GradientDescentOptimizer来调整参数以最小化损失函数

# %%
learning_rate = 0.01
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %% [markdown]
# ## 评估模型

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 100
batch_size = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./tmp/dnn_001.ckpt")
# Out:
# 0 Train accuracy: 0.9 Test accuracy: 0.9031
# 1 Train accuracy: 0.94 Test accuracy: 0.9184
# 2 Train accuracy: 0.92 Test accuracy: 0.9309
# 3 Train accuracy: 0.94 Test accuracy: 0.9364
# 4 Train accuracy: 0.96 Test accuracy: 0.9427
# 5 Train accuracy: 0.98 Test accuracy: 0.9462
# 6 Train accuracy: 0.92 Test accuracy: 0.9492
# 7 Train accuracy: 0.96 Test accuracy: 0.9524
# 8 Train accuracy: 0.98 Test accuracy: 0.9544
# 9 Train accuracy: 0.94 Test accuracy: 0.959
# 10 Train accuracy: 0.92 Test accuracy: 0.96
# 11 Train accuracy: 0.94 Test accuracy: 0.9617
# 12 Train accuracy: 0.98 Test accuracy: 0.9641
# 13 Train accuracy: 1.0 Test accuracy: 0.9653
# 14 Train accuracy: 1.0 Test accuracy: 0.9654
# 15 Train accuracy: 0.98 Test accuracy: 0.966
# 16 Train accuracy: 1.0 Test accuracy: 0.9686
# 17 Train accuracy: 1.0 Test accuracy: 0.9685
# 18 Train accuracy: 1.0 Test accuracy: 0.9701
# 19 Train accuracy: 1.0 Test accuracy: 0.9714
# 20 Train accuracy: 0.98 Test accuracy: 0.971
# ...

# %% [markdown]
# ## 不使用GradientDescentOptimizer，使用别的OP

# %%
def fetch_batch(epoch, batch_index, batch_size):
    np.random.seed(epoch * n_batches + batch_index)  # not shown in the book
    indices = np.random.randint(m, size=batch_size)  # not shown
    X_batch = scaled_housing_data_plus_bias[indices] # not shown
    y_batch = housing.target.reshape(-1, 1)[indices] # not shown
    return X_batch, y_batch

n_inputs = 28 * 28
n_hidden1 = 500
n_hidden2 = 300
n_hidden3 = 100
n_outputs = 10

reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

with tf.name_scope("dnn_2"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                             activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                             activation=tf.nn.relu)
    hidden3 = tf.layers.dense(hidden2, n_hidden3, name="hidden3",
                             activation=tf.nn.relu)
    logits = tf.layers.dense(X, n_hidden1, name="outputs")



with tf.name_scope("loss_2"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    
learning_rate = 0.01
with tf.name_scope("train_2"):
    optimizer = tf.train.AdamOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval_2"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
n_epochs = 100
batch_size = 80
n_batches = int(np.ceil((X_train.size / n_inputs)  / batch_size))
init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./tmp/dnn_002.ckpt")
# Out:
# 0 Train accuracy: 0.9375 Test accuracy: 0.9113
# 1 Train accuracy: 0.8375 Test accuracy: 0.917
# 2 Train accuracy: 0.975 Test accuracy: 0.9136
# 3 Train accuracy: 0.975 Test accuracy: 0.9197
# 4 Train accuracy: 0.875 Test accuracy: 0.9144
# 5 Train accuracy: 0.95 Test accuracy: 0.9139
# 6 Train accuracy: 0.9625 Test accuracy: 0.9161
# 7 Train accuracy: 0.9375 Test accuracy: 0.9197
# 8 Train accuracy: 0.925 Test accuracy: 0.9187
# 9 Train accuracy: 0.925 Test accuracy: 0.9179
# 10 Train accuracy: 0.9875 Test accuracy: 0.9163
# 11 Train accuracy: 0.925 Test accuracy: 0.9172
# 12 Train accuracy: 0.925 Test accuracy: 0.9185
# 13 Train accuracy: 0.8875 Test accuracy: 0.9191
# 14 Train accuracy: 0.95 Test accuracy: 0.9106
# 15 Train accuracy: 0.95 Test accuracy: 0.9167
# 16 Train accuracy: 0.9375 Test accuracy: 0.9197
# 17 Train accuracy: 0.9375 Test accuracy: 0.9176
# 18 Train accuracy: 0.95 Test accuracy: 0.9182
# 19 Train accuracy: 0.95 Test accuracy: 0.9184
# ...
